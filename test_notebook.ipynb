# %% [markdown]
# # Welcome to IPYNB Viewer
#
# This is a **Markdown** cell.
# - It supports lists
# - [Links](https://example.com)
# - `Inline code`
#
# ### Subheader
# Let's test some Python code below.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
x = 5
x + 5
# Out:
# 10

# %%
import pandas as pd
pd.DataFrame({'Name': ['Alice'], 'Age': [30]})
# Out:
#    Name  Age
# 0  Alice   30
